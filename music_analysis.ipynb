# %% [markdown]
# # Spotify API

# %% [markdown]
# ### NOTE
#
# I was going to do more with this, but Spotify removed it's track attribute and analysis API so I can't do any meaningful descriptive stat work with this data. Tried finding a work around, but it was more effort than need be for a relatively simple research question. It's a good thing I caught that the API was depreciated before I gathered all the URIs of their tracks. It would have been interesting to do the data analysis but c'est la vie, it was good practice. On to another thing.

# %%
#importing libraries
import requests
# import base64
from pprint import pprint

# import client id and client secret
from credentials import token_headers

# %% [markdown]
# ## Establishing API credentials
#
# code written with help from this article by Lorela Blaka: https://medium.com/@lorelablaka/extract-data-using-spotify-api-889222835bf4

# %%
# client id and secret
# client_cred = f"{client_id}:{client_secret}"

# need to encode client ID and secret to an encoded string
# client_cred_b64 = base64.b64encode(client_cred.encode())
# client_cred_b64

# %%
# need to specify Token URL and headers and POST method
token_url = "https://accounts.spotify.com/api/token"

token_data = {
    "grant_type": "client_credentials"
}

# token_headers = {
#     "Authorization":f"Basic {client_cred_b64.decode()}"
# }

# %%
# run request using post method
req = requests.post(token_url, data=token_data, headers= token_headers)

# convert the response to JSON
token_response_data = req.json()
req.status_code # want it to be 200
# Out:
# 200

# %%
token_response_data
# Out:
# {'access_token': 'BQCxVrvBTp_-vuteFsxUc980iz0i_9kbeS2nlRNFztoTj8Nltz5PEwagTnQmrZO1FKl7TS1H4kXtlwCWv2wT6DjHeO3MVK-M6I3kXi63d49y6dVPO5AmaQ_LfDPbJRWa_1uRhaay8vo',
#  'token_type': 'Bearer',
#  'expires_in': 3600}

# %%
# making sure the headers have the access token w the token type bearer

access_token = token_response_data["access_token"]
token_type = token_response_data["token_type"]
headers = {
    "Authorization":f"{token_type} {access_token}"
}

# %% [markdown]
# ## Getting the Data

# %%
# artist id
artist_id = "0ghlgldX5Dd6720Q3qFyQB"

# %%
# seeing all the albums
limit = 50
album_url = f"https://api.spotify.com/v1/artists/{artist_id}/albums?include_groups=album&limit={limit}"
album_data = requests.get(album_url, headers=headers).json()
pprint(album_data["items"][0])
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ghlgldX5Dd6720Q3qFyQB'},
#               'href': 'https://api.spotify.com/v1/artists/0ghlgldX5Dd6720Q3qFyQB',
#               'id': '0ghlgldX5Dd6720Q3qFyQB',
#               'name': 'TOMORROW X TOGETHER',
#               'type': 'artist',
#               'uri': 'spotify:artist:0ghlgldX5Dd6720Q3qFyQB'}],
#  'available_markets': ['AR',
#                        'AU',
#                        'AT',
#                        'BE',
#                        'BO',
#                        'BR',
#                        'BG',
#                        'CA',
#                        'CL',
#                        'CO',
#                        'CR',
#                        'CY',
#                        'CZ',
#                        'DK',
#                        'DO',
#                        'DE',
#                        'EC',
#                        'EE',
#                        'SV',
#                        'FI',
#                        'FR',
#                        'GR',
#                        'GT',
#                        'HN',
#                        'HK',
#                        'HU',
#                        'IS',
#                        'IE',
#                        'IT',
#                        'LV',
#                        'LT',
#                        'LU',
#                        'MY',
#                        'MT',
#                        'MX',
#                        'NL',
#                        'NZ',
#                        'NI',
#                        'NO',
#                        'PA',
#                        'PY',
#                        'PE',
#                        'PH',
#                        'PL',
#                        'PT',
#                        'SG',
#                        'SK',
#                        'ES',
#                        'SE',
#                        'CH',
#                        'TW',
#                        'TR',
#                        'UY',
#                        'US',
#                        'GB',
#                        'AD',
#                        'LI',
#                        'MC',
#                        'ID',
#                        'JP',
#                        'TH',
#                        'VN',
#                        'RO',
#                        'IL',
#                        'ZA',
#                        'SA',
#                        'AE',
#                        'BH',
#                        'QA',
#                        'OM',
#                        'KW',
#                        'EG',
#                        'MA',
#                        'DZ',
#                        'TN',
#                        'LB',
#                        'JO',
#                        'PS',
#                        'IN',
#                        'BY',
#                        'KZ',
#                        'MD',
#                        'UA',
#                        'AL',
#                        'BA',
#                        'HR',
#                        'ME',
#                        'MK',
#                        'RS',
#                        'SI',
#                        'KR',
#                        'BD',
#                        'PK',
#                        'LK',
#                        'GH',
#                        'KE',
#                        'NG',
#                        'TZ',
#                        'UG',
#                        'AG',
#                        'AM',
#                        'BS',
#                        'BB',
#                        'BZ',
#                        'BT',
#                        'BW',
#                        'BF',
#                        'CV',
#                        'CW',
#                        'DM',
#                        'FJ',
#                        'GM',
#                        'GE',
#                        'GD',
#                        'GW',
#                        'GY',
#                        'HT',
#                        'JM',
#                        'KI',
#                        'LS',
#                        'LR',
#                        'MW',
#                        'MV',
#                        'ML',
#                        'MH',
#                        'FM',
#                        'NA',
#                        'NR',
#                        'NE',
#                        'PW',
#                        'PG',
#                        'PR',
#                        'WS',
#                        'SM',
#                        'ST',
#                        'SN',
#                        'SC',
#                        'SL',
#                        'SB',
#                        'KN',
#                        'LC',
#                        'VC',
#                        'SR',
#                        'TL',
#                        'TO',
#                        'TT',
#                        'TV',
#                        'VU',
#                        'AZ',
#                        'BN',
#                        'BI',
#                        'KH',
#                        'CM',
#                        'TD',
#                        'KM',
#                        'GQ',
#                        'SZ',
#                        'GA',
#                        'GN',
#                        'KG',
#                        'LA',
#                        'MO',
#                        'MR',
#                        'MN',
#                        'NP',
#                        'RW',
#                        'TG',
#                        'UZ',
#                        'ZW',
#                        'BJ',
#                        'MG',
#                        'MU',
#                        'MZ',
#                        'AO',
#                        'CI',
#                        'DJ',
#                        'ZM',
#                        'CD',
#                        'CG',
#                        'IQ',
#                        'LY',
#                        'TJ',
#                        'VE',
#                        'ET',
#                        'XK'],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/4SFhJGHrFtYqYGIe8VzM6O'},
#  'href': 'https://api.spotify.com/v1/albums/4SFhJGHrFtYqYGIe8VzM6O',
#  'id': '4SFhJGHrFtYqYGIe8VzM6O',
#  'images': [{'height': 640,
#              'url': 'https://i.scdn.co/image/ab67616d0000b27396540ba5f88727371f0fa71b',
#              'width': 640},
#             {'height': 300,
#              'url': 'https://i.scdn.co/image/ab67616d00001e0296540ba5f88727371f0fa71b',
#              'width': 300},
#             {'height': 64,
#              'url': 'https://i.scdn.co/image/ab67616d0000485196540ba5f88727371f0fa71b',
#              'width': 64}],
#  'name': 'The Star Chapter: SANCTUARY (Expanded Edition)',
#  'release_date': '2024-11-08',
#  'release_date_precision': 'day',
#  'total_tracks': 10,
#  'type': 'album',
#  'uri': 'spotify:album:4SFhJGHrFtYqYGIe8VzM6O'}

# %%
# every album name
results = [result["name"] for result in album_data["items"]]
results
# Out:
# ['The Star Chapter: SANCTUARY (Expanded Edition)',
#  'minisode 3: TOMORROW with Remixes',
#  'minisode 3: TOMORROW',
#  'The Name Chapter: FREEFALL',
#  'SWEET',
#  'The Chaos Chapter: FIGHT OR ESCAPE',
#  'The Chaos Chapter: FREEZE',
#  'STILL DREAMING',
#  'The Dream Chapter: MAGIC']

# %%
# now just the eps and singles
ep_url = f"https://api.spotify.com/v1/artists/{artist_id}/albums?include_groups=single&limit={limit}"
ep_data = requests.get(ep_url, headers=headers).json()
results = [result["name"] for result in ep_data["items"]]
results
# Out:
# ['BREWING LOVE, Pt. 5 (Original Soundtrack)',
#  'Love Story [The Seasons: Rainbow of Lee Young Ji]',
#  'The Star Chapter: SANCTUARY',
#  'Open Always Wins',
#  '誓い (CHIKAI)',
#  'Back for More (More Edition)',
#  'Back for More (with Anitta)',
#  'Do It Like That (Jax Jones Remix)',
#  'Do It Like That (Alan Walker Remix)',
#  'Do It Like That (Pop R&B Remix)',
#  'Do It Like That (Jersey Club Remix)',
#  'Do It Like That',
#  '紫陽花のような恋 (Hydrangea Love)',
#  'Sugar Rush Ride (Japanese Ver.)',
#  'Goodbye Now (Love Revolution X TOMORROW X TOGETHER) [Original Webtoon Soundtrack]',
#  'The Name Chapter: TEMPTATION',
#  'Free Falling',
#  'GOOD BOY GONE BAD',
#  '君じゃない誰かの愛し方 (Ring)',
#  'Valley of Lies',
#  "minisode 2: Thursday's Child",
#  'PS5',
#  'Chaotic Wonderland',
#  'EYES (from “Armored Saurus”)',
#  'Ito',
#  '0X1=LOVESONG (I Know I Love You) feat. MOD SUN',
#  '0X1=LOVESONG (I Know I Love You) feat. pH-1, Woodie Gochild, Seori',
#  'Doom at Your Service (Original Television Soundtrack) Pt. 2',
#  'Force',
#  'Your Light (From the Original TV Show "Live On")',
#  'minisode1 : Blue Hour',
#  'DRAMA',
#  'Drama (Japanese Ver.)',
#  'The Dream Chapter: ETERNITY',
#  'MAGIC HOUR',
#  'Our Summer (Acoustic Mix)',
#  'Cat & Dog (English Version)',
#  'The Dream Chapter: STAR']

# %%
# they have 38 singles and eps and like 6 of them are the jonas brother song remixes oh my god so much data
len(results)
# Out:
# 38

# %%
# get artist top tracks
url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"
data = requests.get(url, headers=headers).json()
data["tracks"][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ghlgldX5Dd6720Q3qFyQB'},
#     'href': 'https://api.spotify.com/v1/artists/0ghlgldX5Dd6720Q3qFyQB',
#     'id': '0ghlgldX5Dd6720Q3qFyQB',
#     'name': 'TOMORROW X TOGETHER',
#     'type': 'artist',
#     'uri': 'spotify:artist:0ghlgldX5Dd6720Q3qFyQB'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
#    'MC',
#    'ID',
#    'JP',
#    'TH',
#    'VN',
#    'RO',
#    'IL',
#    'ZA',
#    'SA',
#    'AE',
#    'BH',
#    'QA',
#    'OM',
#    'KW',
#    'EG',
#    'MA',
#    'DZ',
#    'TN',
#    'LB',
#    'JO',
#    'PS',
#    'IN',
#    'BY',
#    'KZ',
#    'MD',
#    'UA',
#    'AL',
#    'BA',
#    'HR',
#    'ME',
#    'MK',
#    'RS',
#    'SI',
#    'KR',
#    'BD',
#    'PK',
#    'LK',
#    'GH',
#    'KE',
#    'NG',
#    'TZ',
#    'UG',
#    'AG',
#    'AM',
#    'BS',
#    'BB',
#    'BZ',
#    'BT',
#    'BW',
#    'BF',
#    'CV',
#    'CW',
#    'DM',
#    'FJ',
#    'GM',
#    'GE',
#    'GD',
#    'GW',
#    'GY',
#    'HT',
#    'JM',
#    'KI',
#    'LS',
#    'LR',
#    'MW',
#    'MV',
#    'ML',
#    'MH',
#    'FM',
#    'NA',
#    'NR',
#    'NE',
#    'PW',
#    'PG',
#    'PR',
#    'WS',
#    'SM',
#    'ST',
#    'SN',
#    'SC',
#    'SL',
#    'SB',
#    'KN',
#    'LC',
#    'VC',
#    'SR',
#    'TL',
#    'TO',
#    'TT',
#    'TV',
#    'VU',
#    'AZ',
#    'BN',
#    'BI',
#    'KH',
#    'CM',
#    'TD',
#    'KM',
#    'GQ',
#    'SZ',
#    'GA',
#    'GN',
#    'KG',
#    'LA',
#    'MO',
#    'MR',
#    'MN',
#    'NP',
#    'RW',
#    'TG',
#    'UZ',
#    'ZW',
#    'BJ',
#    'MG',
#    'MU',
#    'MZ',
#    'AO',
#    'CI',
#    'DJ',
#    'ZM',
#    'CD',
#    'CG',
#    'IQ',
#    'LY',
#    'TJ',
#    'VE',
#    'ET',
#    'XK'],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4SFhJGHrFtYqYGIe8VzM6O'},
#   'href': 'https://api.spotify.com/v1/albums/4SFhJGHrFtYqYGIe8VzM6O',
#   'id': '4SFhJGHrFtYqYGIe8VzM6O',
#   'images': [{'url': 'https://i.scdn.co/image/ab67616d0000b27396540ba5f88727371f0fa71b',
#     'height': 640,
#     'width': 640},
#    {'url': 'https://i.scdn.co/image/ab67616d00001e0296540ba5f88727371f0fa71b',
#     'height': 300,
#     'width': 300},
#    {'url': 'https://i.scdn.co/image/ab67616d0000485196540ba5f88727371f0fa71b',
#     'height': 64,
#     'width': 64}],
#   'is_playable': True,
#   'name': 'The Star Chapter: SANCTUARY (Expanded Edition)',
#   'release_date': '2024-11-08',
#   'release_date_precision': 'day',
#   'total_tracks': 10,
#   'type': 'album',
#   'uri': 'spotify:album:4SFhJGHrFtYqYGIe8VzM6O'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0ghlgldX5Dd6720Q3qFyQB'},
#    'href': 'https://api.spotify.com/v1/artists/0ghlgldX5Dd6720Q3qFyQB',
#    'id': '0ghlgldX5Dd6720Q3qFyQB',
#    'name': 'TOMORROW X TOGETHER',
#    'type': 'artist',
#    'uri': 'spotify:artist:0ghlgldX5Dd6720Q3qFyQB'}],
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'BY',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
#   'UG',
#   'AG',
#   'AM',
#   'BS',
#   'BB',
#   'BZ',
#   'BT',
#   'BW',
#   'BF',
#   'CV',
#   'CW',
#   'DM',
#   'FJ',
#   'GM',
#   'GE',
#   'GD',
#   'GW',
#   'GY',
#   'HT',
#   'JM',
#   'KI',
#   'LS',
#   'LR',
#   'MW',
#   'MV',
#   'ML',
#   'MH',
#   'FM',
#   'NA',
#   'NR',
#   'NE',
#   'PW',
#   'PG',
#   'PR',
#   'WS',
#   'SM',
#   'ST',
#   'SN',
#   'SC',
#   'SL',
#   'SB',
#   'KN',
#   'LC',
#   'VC',
#   'SR',
#   'TL',
#   'TO',
#   'TT',
#   'TV',
#   'VU',
#   'AZ',
#   'BN',
#   'BI',
#   'KH',
#   'CM',
#   'TD',
#   'KM',
#   'GQ',
#   'SZ',
#   'GA',
#   'GN',
#   'KG',
#   'LA',
#   'MO',
#   'MR',
#   'MN',
#   'NP',
#   'RW',
#   'TG',
#   'UZ',
#   'ZW',
#   'BJ',
#   'MG',
#   'MU',
#   'MZ',
#   'AO',
#   'CI',
#   'DJ',
#   'ZM',
#   'CD',
#   'CG',
#   'IQ',
#   'LY',
#   'TJ',
#   'VE',
#   'ET',
#   'XK'],
#  'disc_number': 1,
#  'duration_ms': 157149,
#  'explicit': False,
#  'external_ids': {'isrc': 'USA2P2461745'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/6ZpoRaO2cfXR1dti2N4TLs'},
#  'href': 'https://api.spotify.com/v1/tracks/6ZpoRaO2cfXR1dti2N4TLs',
#  'id': '6ZpoRaO2cfXR1dti2N4TLs',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Over The Moon',
#  'popularity': 69,
#  'preview_url': None,
#  'track_number': 2,
#  'type': 'track',
#  'uri': 'spotify:track:6ZpoRaO2cfXR1dti2N4TLs'}

# %%
results = [result["name"] for result in data["tracks"]]
results
# Out:
# ['Over The Moon',
#  'Deja Vu',
#  '0X1=LOVESONG (I Know I Love You) feat. Seori',
#  'Sugar Rush Ride',
#  'Heaven',
#  'Tinnitus (Wanna be a rock)',
#  'LO$ER=LO♡ER',
#  'I’ll See You There Tomorrow',
#  'Surfing in the Moonlight',
#  'Chasing That Feeling']
